# %% [markdown]
# <a href="https://colab.research.google.com/github/karalius32/HackatonAI/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
#!pip install "tensorflow>=2.0.0"
#!pip install --upgrade tensorflow-hub
#!pip install tensorflow.compat.v1
#!pip install --upgrade simple_elmo

from simple_elmo import ElmoModel
import tensorflow as tf
import tensorflow_hub as hub

# %%
trainFile = open('/content/all_articles_with_questions_train.csv')

lines = csv.reader(trainFile)
header = next(lines)

questions = []
answers = []
symbols = []


for line in lines:
  questions.append(line[0])
  answers.append(line[1])
  symbols.append(line[2])

questions = questions[:100]
answers = answers[:100]
print(len(questions))
print(len(answers))
# Out:
# 100
# 100

# %%
#simple-elmo realization
model = ElmoModel()
#download from https://allenai.org/allennlp/software/elmo, in the folder goes hdf5 and json files
#kazkodel neleidzia antra karta leisti to model load, tenka restarting sesija
model.load("/content/ELMO", max_batch_size=8)
# Out:
# /usr/local/lib/python3.10/dist-packages/simple_elmo/model.py:531: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   lstm_cell = tf.compat.v1.nn.rnn_cell.LSTMCell(
# 'The model is now loaded.'

# %%
answerEmbeddings = model.get_elmo_vectors(answers) #duoda errora RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[8,1024,6267,44] kai paduodamas 100 ilgio stringu masyvas, tai 6267 turetu but 100, kazkodel nera
questionEmbeddings = model.get_elmo_vectors(questions)
print(questionEmbeddings[0][0])
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1401     try:
# -> 1402       return fn(*args)
#    1403     except errors.OpError as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1384       self._extend_graph()
# -> 1385       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1386                                       target_list, run_metadata)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1477                           run_metadata):
# ...
